# %%
import pandas as pd
import matplotlib.pyplot as plt

from neuralforecast.models import TimesNet
from neuralforecast.core import NeuralForecast

import logging
logging.getLogger("pytorch_lightning").setLevel(logging.WARNING)

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # data

# %%
df = pd.read_csv("https://datasets-nixtla.s3.amazonaws.com/EPF_FR_BE.csv")
df["ds"] = pd.to_datetime(df["ds"])

futr_df= pd.read_csv("https://datasets-nixtla.s3.amazonaws.com/EPF_FR_BE_futr.csv")
futr_df["ds"] = pd.to_datetime(futr_df["ds"])

# %%
print(df.head())
print()
print(df.tail())
print()
print(df.shape)
print()
print(df["unique_id"].value_counts())
# Out:
#   unique_id                  ds      y  gen_forecast  system_load  week_day
# 0        FR 2015-01-01 00:00:00  53.48       76905.0      74812.0         3
# 1        FR 2015-01-01 01:00:00  51.93       75492.0      71469.0         3
# 2        FR 2015-01-01 02:00:00  48.76       74394.0      69642.0         3
# 3        FR 2015-01-01 03:00:00  42.27       72639.0      66704.0         3
# 4        FR 2015-01-01 04:00:00  38.41       69347.0      65051.0         3
#
#       unique_id                  ds      y  gen_forecast  system_load  \
# 32155        BE 2016-10-31 19:00:00  65.83       55041.0      59537.0
# 32156        BE 2016-10-31 20:00:00  56.11       53535.0      53823.0
# 32157        BE 2016-10-31 21:00:00  40.26       49893.0      50622.0
# 32158        BE 2016-10-31 22:00:00  38.62       49037.0      49194.0
# 32159        BE 2016-10-31 23:00:00  38.65       49094.0      53441.0
#
#        week_day
# 32155         0
# 32156         0
# 32157         0
# 32158         0
# 32159         0
#
# (32160, 6)
#
# FR    16080
# BE    16080
# Name: unique_id, dtype: int64

# %%
print(futr_df.head())
print()
print(futr_df.shape)
print()
print(futr_df["unique_id"].value_counts())
# Out:
#   unique_id                  ds  gen_forecast  week_day
# 0        FR 2016-11-01 00:00:00       49118.0         1
# 1        FR 2016-11-01 01:00:00       47890.0         1
# 2        FR 2016-11-01 02:00:00       47158.0         1
# 3        FR 2016-11-01 03:00:00       45991.0         1
# 4        FR 2016-11-01 04:00:00       45378.0         1
#
# (48, 4)
#
# FR    24
# BE    24
# Name: unique_id, dtype: int64

# %% [markdown]
# # time series scaling: 训练前

# %% [markdown]
# ## model training

# %%
horizon = 24
nf = NeuralForecast(
    models = [
        TimesNet(
            h = horizon,
            input_size = 5 * horizon,
            max_steps = 100,
            top_k = 3,  # number of periods for FFT
            num_kernels = 3,  # number of kernels for Inception module
            batch_size = 2,
            windows_batch_size = 32,
            learning_rate = 0.001,
            futr_exog_list = [
                "gen_forecast", 
                # "system_load", 
                "week_day"
            ],
            scaler_type = None,
        )
    ],
    freq = "h",
    local_scaler_type = "standard"
)
nf.fit(df = df)
# Out:
# Global seed set to 1
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]

# %% [markdown]
# ## model predicting

# %%
Y_hat_df = nf.predict(futr_df = futr_df)
Y_hat_df
# Out:
# Predicting: 0it [00:00, ?it/s]
#                            ds   TimesNet
# unique_id
# BE        2016-11-01 00:00:00  39.334202
# BE        2016-11-01 01:00:00  33.489193
# BE        2016-11-01 02:00:00  27.820333
# BE        2016-11-01 03:00:00  29.735058
# BE        2016-11-01 04:00:00  32.169380
# BE        2016-11-01 05:00:00  37.232624
# BE        2016-11-01 06:00:00  48.976028
# BE        2016-11-01 07:00:00  54.249825
# BE        2016-11-01 08:00:00  54.550694
# BE        2016-11-01 09:00:00  55.810600
# BE        2016-11-01 10:00:00  53.651009
# BE        2016-11-01 11:00:00  51.105560
# BE        2016-11-01 12:00:00  51.227608
# BE        2016-11-01 13:00:00  50.950790
# BE        2016-11-01 14:00:00  48.470345
# BE        2016-11-01 15:00:00  53.237278
# BE        2016-11-01 16:00:00  53.657261
# BE        2016-11-01 17:00:00  55.115662
# BE        2016-11-01 18:00:00  58.532417
# BE        2016-11-01 19:00:00  58.234787
# BE        2016-11-01 20:00:00  63.783367
# BE        2016-11-01 21:00:00  60.862984
# BE        2016-11-01 22:00:00  59.870148
# BE        2016-11-01 23:00:00  55.677917
# FR        2016-11-01 00:00:00  43.000263
# FR        2016-11-01 01:00:00  37.498634
# FR        2016-11-01 02:00:00  31.543571
# FR        2016-11-01 03:00:00  33.548050
# FR        2016-11-01 04:00:00  35.497959
# FR        2016-11-01 05:00:00  38.959648
# FR        2016-11-01 06:00:00  47.246792
# FR        2016-11-01 07:00:00  50.102562
# FR        2016-11-01 08:00:00  51.010506
# FR        2016-11-01 09:00:00  55.039448
# FR        2016-11-01 10:00:00  52.682274
# FR        2016-11-01 11:00:00  49.081482
# FR        2016-11-01 12:00:00  48.893806
# FR        2016-11-01 13:00:00  50.078705
# FR        2016-11-01 14:00:00  46.553268
# FR        2016-11-01 15:00:00  50.317577
# FR        2016-11-01 16:00:00  49.420216
# FR        2016-11-01 17:00:00  51.031624
# FR        2016-11-01 18:00:00  54.003914
# FR        2016-11-01 19:00:00  55.672531
# FR        2016-11-01 20:00:00  56.607445
# FR        2016-11-01 21:00:00  56.274864
# FR        2016-11-01 22:00:00  54.845566
# FR        2016-11-01 23:00:00  52.881172

# %% [markdown]
# ## result

# %%
Y_hat_df = Y_hat_df.reset_index(drop=False)

# %%
plot_df = df[df['unique_id']=='FR'].tail(24*5).reset_index(drop=True)
Y_hat_df_FR = Y_hat_df[Y_hat_df['unique_id']=='FR']
plot_df = pd.concat([plot_df, Y_hat_df_FR ]).set_index('ds')

plot_df[['y', 'TimesNet']].plot(linewidth=1.5)
plt.axvline(pd.to_datetime('2016-11-01'), color='red')
plt.ylabel('Price [EUR/MWh]', fontsize=12)
plt.xlabel('Date', fontsize=12)
plt.grid()

# %%
plot_df = df[df['unique_id']=='BE'].tail(24*5).reset_index(drop=True)
Y_hat_df_BE = Y_hat_df[Y_hat_df['unique_id']=='BE']
plot_df = pd.concat([plot_df, Y_hat_df_BE ]).set_index('ds')

plot_df[['y', 'TimesNet']].plot(linewidth=1.5)
plt.axvline(pd.to_datetime('2016-11-01'), color='red')
plt.ylabel('Price [EUR/MWh]', fontsize=12)
plt.xlabel('Date', fontsize=12)
plt.grid()

# %% [markdown]
# # temporal window normalization: 训练中

# %% [markdown]
# ## model training

# %%
horizon = 24
nf = NeuralForecast(
    models = [
        TimesNet(
            h = horizon,
            input_size = 5 * horizon,
            max_steps = 100,
            top_k = 3,  # number of periods for FFT
            num_kernels = 3,  # number of kernels for Inception module
            batch_size = 2,
            windows_batch_size = 32,
            learning_rate = 0.001,
            futr_exog_list = [
                "gen_forecast", 
                # "system_load", 
                "week_day"
            ],
            scaler_type = "robust",
        )
    ],
    freq = "h",
    local_scaler_type = None,  # 避免在训练前缩放数据
)
nf.fit(df = df)
# Out:
# Global seed set to 1
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]

# %% [markdown]
# ## model predicting

# %%
Y_hat_df = nf.predict(futr_df = futr_df)
Y_hat_df
# Out:
# Predicting: 0it [00:00, ?it/s]
#                            ds   TimesNet
# unique_id
# BE        2016-11-01 00:00:00  39.190975
# BE        2016-11-01 01:00:00  34.760071
# BE        2016-11-01 02:00:00  32.164352
# BE        2016-11-01 03:00:00  30.992968
# BE        2016-11-01 04:00:00  31.442944
# BE        2016-11-01 05:00:00  41.939621
# BE        2016-11-01 06:00:00  52.510082
# BE        2016-11-01 07:00:00  66.773331
# BE        2016-11-01 08:00:00  68.990288
# BE        2016-11-01 09:00:00  69.964264
# BE        2016-11-01 10:00:00  68.511230
# BE        2016-11-01 11:00:00  63.706482
# BE        2016-11-01 12:00:00  63.488010
# BE        2016-11-01 13:00:00  60.742744
# BE        2016-11-01 14:00:00  60.217335
# BE        2016-11-01 15:00:00  59.309826
# BE        2016-11-01 16:00:00  60.509514
# BE        2016-11-01 17:00:00  59.209179
# BE        2016-11-01 18:00:00  62.646133
# BE        2016-11-01 19:00:00  62.824665
# BE        2016-11-01 20:00:00  63.581161
# BE        2016-11-01 21:00:00  60.187355
# BE        2016-11-01 22:00:00  55.766747
# BE        2016-11-01 23:00:00  51.862183
# FR        2016-11-01 00:00:00  44.174328
# FR        2016-11-01 01:00:00  40.451073
# FR        2016-11-01 02:00:00  37.117828
# FR        2016-11-01 03:00:00  36.487019
# FR        2016-11-01 04:00:00  36.195770
# FR        2016-11-01 05:00:00  44.318325
# FR        2016-11-01 06:00:00  53.920727
# FR        2016-11-01 07:00:00  66.749969
# FR        2016-11-01 08:00:00  68.750664
# FR        2016-11-01 09:00:00  69.923912
# FR        2016-11-01 10:00:00  68.732803
# FR        2016-11-01 11:00:00  64.266960
# FR        2016-11-01 12:00:00  63.853081
# FR        2016-11-01 13:00:00  61.250923
# FR        2016-11-01 14:00:00  60.409286
# FR        2016-11-01 15:00:00  59.396275
# FR        2016-11-01 16:00:00  59.829918
# FR        2016-11-01 17:00:00  59.699612
# FR        2016-11-01 18:00:00  63.278313
# FR        2016-11-01 19:00:00  63.799526
# FR        2016-11-01 20:00:00  64.978210
# FR        2016-11-01 21:00:00  61.724247
# FR        2016-11-01 22:00:00  57.860550
# FR        2016-11-01 23:00:00  54.085369

# %% [markdown]
# ## result

# %%
Y_hat_df = Y_hat_df.reset_index(drop=False)

# %%
plot_df = df[df['unique_id']=='FR'].tail(24*5).reset_index(drop=True)
Y_hat_df_FR = Y_hat_df[Y_hat_df['unique_id']=='FR']
plot_df = pd.concat([plot_df, Y_hat_df_FR ]).set_index('ds')

plot_df[['y', 'TimesNet']].plot(linewidth=1.5)
plt.axvline(pd.to_datetime('2016-11-01'), color='red')
plt.ylabel('Price [EUR/MWh]', fontsize=12)
plt.xlabel('Date', fontsize=12)
plt.grid()

# %%
plot_df = df[df['unique_id']=='BE'].tail(24*5).reset_index(drop=True)
Y_hat_df_FR = Y_hat_df[Y_hat_df['unique_id']=='BE']
plot_df = pd.concat([plot_df, Y_hat_df_FR ]).set_index('ds')

plot_df[['y', 'TimesNet']].plot(linewidth=1.5)
plt.axvline(pd.to_datetime('2016-11-01'), color='red')
plt.ylabel('Price [EUR/MWh]', fontsize=12)
plt.xlabel('Date', fontsize=12)
plt.grid()
