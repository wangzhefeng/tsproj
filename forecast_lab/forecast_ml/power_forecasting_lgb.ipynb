# %%
import pandas as pd
import matplotlib.pyplot as plt
from utilsforecast.plotting import plot_series

# data
from mlforecast.utils import generate_daily_series
# model
from mlforecast import MLForecast
import lightgbm as lgb
# feature engine
from mlforecast.lag_transforms import ExpandingMean, RollingMean
from mlforecast.target_transforms import Differences

# %% [markdown]
# # data

# %%
series = generate_daily_series(
    n_series = 20,
    max_length = 100,
    n_static_features = 1,
    static_as_categorical = False,
    with_trend = True,
)
print(series.head())
print()
print(series.shape)
print()
print(series["unique_id"].value_counts())
# Out:
#   unique_id         ds           y  static_0
# 0     id_00 2000-01-01   17.519167        72
# 1     id_00 2000-01-02   87.799695        72
# 2     id_00 2000-01-03  177.442975        72
# 3     id_00 2000-01-04  232.704110        72
# 4     id_00 2000-01-05  317.510474        72
#
# (1461, 4)
#
# unique_id
# id_09    100
# id_01     97
# id_00     94
# id_05     89
# id_18     89
# id_17     88
# id_10     86
# id_13     74
# id_14     74
# id_11     73
# id_19     73
# id_08     71
# id_07     69
# id_15     62
# id_06     59
# id_12     56
# id_04     53
# id_03     53
# id_16     51
# id_02     50
# Name: count, dtype: int64

# %% [markdown]
# # Forecasting

# %% [markdown]
# ## model

# %%
fcst = MLForecast(
    models = [
        lgb.LGBMRegressor(random_state = 0, verbosity = -1),
    ],
    freq = "15min",
    lags = [7, 14],
    lag_transforms = {
        1: [ExpandingMean()],
        7: [RollingMean(window_size = 28)]
    },
    date_features = ["dayofweek"],
    target_transforms = [Differences([1])],
)

# %% [markdown]
# ## feature engine

# %%
prep_data = fcst.preprocess(series)
with pd.option_context("display.max_columns", None):
    print(prep_data.head(20))
    print()
    print(prep_data.shape)
    print()
    print(prep_data["unique_id"].value_counts())
# Out:
#    unique_id         ds           y  static_0        lag7       lag14  \
# 35     id_00 2000-02-05 -430.702596        72 -454.058620 -456.530375
# 36     id_00 2000-02-06   87.790540        72   79.416692   70.494425
# 37     id_00 2000-02-07   68.248825        72   84.021957   80.358734
# 38     id_00 2000-02-08   63.141455        72   44.151060   67.095036
# 39     id_00 2000-02-09   63.001354        72  105.237348   76.114648
# 40     id_00 2000-02-10   95.211525        72   61.904630   79.455167
# 41     id_00 2000-02-11   85.313695        72   55.861639   92.301047
# 42     id_00 2000-02-12 -448.711752        72 -430.702596 -454.058620
# 43     id_00 2000-02-13   72.815852        72   87.790540   79.416692
# 44     id_00 2000-02-14   86.611835        72   68.248825   84.021957
# 45     id_00 2000-02-15   58.372153        72   63.141455   44.151060
# 46     id_00 2000-02-16   67.349966        72   63.001354  105.237348
# 47     id_00 2000-02-17   75.665055        72   95.211525   61.904630
# 48     id_00 2000-02-18   78.894710        72   85.313695   55.861639
# 49     id_00 2000-02-19 -447.957791        72 -448.711752 -430.702596
# 50     id_00 2000-02-20   85.754232        72   72.815852   87.790540
# 51     id_00 2000-02-21   60.412454        72   86.611835   68.248825
# 52     id_00 2000-02-22   90.294797        72   58.372153   63.141455
# 53     id_00 2000-02-23   79.712783        72   67.349966   63.001354
# 54     id_00 2000-02-24   62.985937        72   75.665055   95.211525
#
#     expanding_mean_lag1  rolling_mean_lag7_window_size28  dayofweek
# 35            13.013610                         0.423907          5
# 36             0.336004                         0.750199          6
# 37             2.765297                         0.549437          0
# 38             4.535122                         0.152649          1
# 39             6.077394                         0.882327          2
# 40             7.536982                         0.834436          3
# 41             9.728846                        -0.561877          4
# 42            11.572379                         0.746970          5
# 43             0.613233                         0.307402          6
# 44             2.292364                         0.638019          0
# 45             4.208715                        -0.157272          1
# 46             5.412347                        -0.165339          2
# 47             6.758817                         0.404904          3
# 48             8.224907                         0.773713          4
# 49             9.697195                         0.555304          5
# 50             0.357297                         0.590390          6
# 51             2.065236                         0.771584          0
# 52             3.209299                         1.083475          1
# 53             4.884020                         0.385837          2
# 54             6.295884                         0.838955          3
#
# (761, 9)
#
# unique_id
# id_09    65
# id_01    62
# id_00    59
# id_05    54
# id_18    54
# id_17    53
# id_10    51
# id_13    39
# id_14    39
# id_11    38
# id_19    38
# id_08    36
# id_07    34
# id_15    27
# id_06    24
# id_12    21
# id_04    18
# id_03    18
# id_16    16
# id_02    15
# Name: count, dtype: int64

# %% [markdown]
# ## training

# %%
fcst.fit(series)
# Out:
# MLForecast(models=[LGBMRegressor], freq=15min, lag_features=['lag7', 'lag14', 'expanding_mean_lag1', 'rolling_mean_lag7_window_size28'], date_features=['dayofweek'], num_threads=1)

# %% [markdown]
# ## predict

# %%
predictions = fcst.predict(14)
predictions
# Out:
#     unique_id                  ds  LGBMRegressor
# 0       id_00 2000-04-03 00:15:00     299.418009
# 1       id_00 2000-04-03 00:30:00     365.337882
# 2       id_00 2000-04-03 00:45:00     435.882746
# 3       id_00 2000-04-03 01:00:00     499.342690
# 4       id_00 2000-04-03 01:15:00      56.818299
# ..        ...                 ...            ...
# 275     id_19 2000-03-13 02:30:00      27.911043
# 276     id_19 2000-03-13 02:45:00      38.003915
# 277     id_19 2000-03-13 03:00:00      46.675636
# 278     id_19 2000-03-13 03:15:00      54.514102
# 279     id_19 2000-03-13 03:30:00      60.254441
#
# [280 rows x 3 columns]

# %% [markdown]
# ## prediction

# %%
fig = plot_series(series, predictions, max_ids = 4, plot_random = False)
fig
