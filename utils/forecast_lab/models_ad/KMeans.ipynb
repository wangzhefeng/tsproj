# %%
from darts.datasets import ETTh2Dataset
from darts.ad import KMeansScorer

# %%
series = ETTh2Dataset().load()[:10000][["MUFL", "LULL"]]
series
# Out:
# <TimeSeries (DataArray) (date: 17420, component: 7, sample: 1)>
# array([[[ 41.13000107],
#         [ 12.48099995],
#         [ 36.5359993 ],
#         ...,
#         [  4.42399979],
#         [  1.31099999],
#         [ 38.66199875]],
#
#        [[ 37.52799988],
#         [ 10.13599968],
#         [ 33.93600082],
#         ...,
#         [  4.43499994],
#         [  1.21500003],
#         [ 37.12400055]],
#
#        [[ 37.9469986 ],
#         [ 11.30900002],
#         [ 35.33000183],
#         ...,
# ...
#         ...,
#         [-11.55700016],
#         [ -1.41799998],
#         [ 48.18349838]],
#
#        [[ 43.64300156],
#         [ 13.40299988],
#         [ 54.73699951],
#         ...,
#         [-10.29899979],
#         [ -1.41799998],
#         [ 46.8655014 ]],
#
#        [[ 38.86800003],
#         [ 10.05200005],
#         [ 49.85900116],
#         ...,
#         [-11.52499962],
#         [ -1.41799998],
#         [ 45.98649979]]])
# Coordinates:
#   * date       (date) datetime64[ns] 2016-07-01 ... 2018-06-26T19:00:00
#   * component  (component) object 'HUFL' 'HULL' 'MUFL' 'MULL' 'LUFL' 'LULL' 'OT'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
train, val = series.split_before(split_point = 0.6)
