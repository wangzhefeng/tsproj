# %%
import numpy as np

from sktime.datasets import load_airline
from sktime.forecasting.naive import NaiveForecaster
from sktime.utils.plotting import plot_series

# %% [markdown]
# # data

# %%
y = load_airline()
y
# Out:
# Period
# 1949-01    112.0
# 1949-02    118.0
# 1949-03    132.0
# 1949-04    129.0
# 1949-05    121.0
#            ...
# 1960-08    606.0
# 1960-09    508.0
# 1960-10    461.0
# 1960-11    390.0
# 1960-12    432.0
# Freq: M, Name: Number of airline passengers, Length: 144, dtype: float64

# %% [markdown]
# # forecast

# %%
fcst = NaiveForecaster(strategy="last", sp=12)
fcst
# Out:
# NaiveForecaster(sp=12)

# %% [markdown]
# # model fit

# %%
# forecast horizon: predict next 36 months
fh = np.arange(1, 37)
# model fit
fcst.fit(y, fh = fh)
# Out:
# NaiveForecaster(sp=12)

# %% [markdown]
# # model predict

# %%
y_pred = fcst.predict()
y_pred
# Out:
# 1961-01    417.0
# 1961-02    391.0
# 1961-03    419.0
# 1961-04    461.0
# 1961-05    472.0
# 1961-06    535.0
# 1961-07    622.0
# 1961-08    606.0
# 1961-09    508.0
# 1961-10    461.0
# 1961-11    390.0
# 1961-12    432.0
# 1962-01    417.0
# 1962-02    391.0
# 1962-03    419.0
# 1962-04    461.0
# 1962-05    472.0
# 1962-06    535.0
# 1962-07    622.0
# 1962-08    606.0
# 1962-09    508.0
# 1962-10    461.0
# 1962-11    390.0
# 1962-12    432.0
# 1963-01    417.0
# 1963-02    391.0
# 1963-03    419.0
# 1963-04    461.0
# 1963-05    472.0
# 1963-06    535.0
# 1963-07    622.0
# 1963-08    606.0
# 1963-09    508.0
# 1963-10    461.0
# 1963-11    390.0
# 1963-12    432.0
# Freq: M, Name: Number of airline passengers, dtype: float64

# %% [markdown]
# # result

# %%
fig, ax = plot_series(y, y_pred, labels=["train", "pred"])
